# %%
import pandas as pd

# %%
df = pd.read_csv('spotify_millsongdata.csv')

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df = df.drop('link',axis = 1).reset_index(drop = True)

# %%
df.head(10)
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
# 5   ABBA     Burning My Bridges
# 6   ABBA              Cassandra
# 7   ABBA             Chiquitita
# 8   ABBA            Crazy World
# 9   ABBA        Crying Over You
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
# 5  Well, you hoot and you holler and you make me ...
# 6  Down in the street they're all singing and sho...
# 7  Chiquitita, tell me what's wrong  \r\nYou're e...
# 8  I was out with the morning sun  \r\nCouldn't s...
# 9  I'm waitin' for you baby  \r\nI'm sitting all ...

# %%
df['text'][0]
# Out:
# "Look at her face, it's a wonderful face  \r\nAnd it means something special to me  \r\nLook at the way that she smiles when she sees me  \r\nHow lucky can one fellow be?  \r\n  \r\nShe's just my kind of girl, she makes me feel fine  \r\nWho could ever believe that she could be mine?  \r\nShe's just my kind of girl, without her I'm blue  \r\nAnd if she ever leaves me what could I do, what could I do?  \r\n  \r\nAnd when we go for a walk in the park  \r\nAnd she holds me and squeezes my hand  \r\nWe'll go on walking for hours and talking  \r\nAbout all the things that we plan  \r\n  \r\nShe's just my kind of girl, she makes me feel fine  \r\nWho could ever believe that she could be mine?  \r\nShe's just my kind of girl, without her I'm blue  \r\nAnd if she ever leaves me what could I do, what could I do?\r\n\r\n"

# %%
df.sample(5000)
# Out:
#                 artist                              song  \
# 32473     Fall Out Boy        I Write Sins Not Tragedies
# 17053     Randy Travis                          Our King
# 45849      Nina Simone             Falling In Love Again
# 41824    Lionel Richie              Love Will Find A Way
# 40116     Kenny Rogers                      Reuben James
# ...                ...                               ...
# 12233  Luther Vandross  My Sensitivity (Gets In The Way)
# 22618          Zoegirl                        You Get Me
# 2500       Cheap Trick                        Who D'king
# 53591        Tom Waits                         Last Leaf
# 23481  Alice In Chains                             Alone
#
#                                                     text
# 32473  [Originally By Panic At! The Disco]  \r\n  \r\...
# 17053  About a thousand years before it came to pass ...
# 45849  Falling in love again I never wanted to  \r\nW...
# 41824  Are you feeling down, and lonely.  \r\nFeeling...
# 40116  Ruben James, in my song you live again  \r\nAn...
# ...                                                  ...
# 12233  At times I don't believe that I can't control ...
# 22618  V1 Wonderful is what i perceived  \r\nthis lif...
# 2500   Don't call me baby  \r\nDon't call me your ins...
# 53591  I'm the last leaf on the tree  \r\nThe autumn ...
# 23481  It's been a long day at the bottom of the hill...
#
# [5000 rows x 3 columns]

# %%
df = df.sample(5000)

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# ## Text Cleaning/ Preprocessing

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s',' ').replace(r'\n',' ',regex = True)

# %%
# Tokenization, Vectorization, Cosine Similarity. Content - Based System(Tag Based)

# %%
df
# Out:
#                    artist                       song  \
# 45832         Nina Simone               Blue Prelude
# 51585        Selena Gomez            Write Your Name
# 14021          Nick Drake                  River Man
# 6376        Frank Sinatra        Don't Wait Too Long
# 22442           Zebrahead        Postcards From Hell
# ...                   ...                        ...
# 28692  Dave Matthews Band                  Baby Blue
# 53562         Tom T. Hall                Way We Were
# 31634    Enrique Iglesias  Don't You Forget About Me
# 37317              J Cole               Miss America
# 5120       Emmylou Harris        If I Could Be There
#
#                                                     text
# 45832  let me sigh, let me cry when i'm blue,  \r let...
# 51585  take my arm, take my head  \r make your mark l...
# 14021  betty came by on her way  \r said she had a wo...
# 6376   you are the summer and i am the autumn  \r don...
# 22442  i didn't see the signs posted on the road  \r ...
# ...                                                  ...
# 28692  confess, your kiss still knocks me off my legs...
# 53562  memories light the corners of my mind  \r mist...
# 31634  they say love is just a game  \r they say time...
# 37317  this is a public service announcement  \r brou...
# 5120   if i could be there i'd be there tonight comfo...
#
# [5000 rows x 3 columns]

# %%
import nltk
nltk.download('punkt')
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MITALI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
    token = nltk.word_tokenize(txt)
    a = [stemmer.stem(w) for w in token]
    return " ".join(a)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x:token(x))
# Out:
# 45832    let me sigh , let me cri when i 'm blue , let ...
# 51585    take my arm , take my head make your mark like...
# 14021    betti came by on her way said she had a word t...
# 6376     you are the summer and i am the autumn do n't ...
# 22442    i did n't see the sign post on the road dead e...
#                                ...
# 28692    confess , your kiss still knock me off my leg ...
# 53562    memori light the corner of my mind misti water...
# 31634    they say love is just a game they say time can...
# 37317    thi is a public servic announc brought to you ...
# 5120     if i could be there i 'd be there tonight comf...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
